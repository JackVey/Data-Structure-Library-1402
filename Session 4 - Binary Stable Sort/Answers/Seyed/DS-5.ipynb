# %% [markdown]
# # seyed ali hoseiny nasab 401222047
# # navid ebadi 401222093
# radix sort vs python sort

# %%
import time
import random
from math import sqrt,ceil,floor
import matplotlib.pyplot as plt

# %%
def randList(seed, n):
    return [random.randint(0,1000) for x in range(n)]


def BlockSwap(A, p, q):
    for i in range(0, q-p):
        (A[p+i], A[q+i]) = (A[q+i], A[p+i])


def StableRBA(A, p, q, r):
    n0 = r-q
    n1 = q-p
    if n1 == 0:
        return r
    while n0 > 0:
        if n1 > n0:
            p = q-n0
            BlockSwap(A, p, q)
            n1 = n1-n0
            q = p
            p = p-n1
        else:
            BlockSwap(A, p, q)
            n0 = n0-n1
            p = q
            q = q+n1
    return p


def BinaryStableSort(A, p, r):
    if r-p > 1:
        q = (p+r)//2
        p = BinaryStableSort(A, p, q)
        r = BinaryStableSort(A, q, r)
        p = StableRBA(A, p, q, r)
    elif radixkey(A[p])==0 :
        return r
    return p


mask = 1
def radixkey(x):
    return x & mask

def inplaceRadixSort(x, n):
    global mask
    mask = 1
    for _ in range(32):
        BinaryStableSort(x, 0, n)
        mask <<= 1

# %%
x = []
average = []
minTime = []
maxTime = []
for i in range(1,11):
    n = i*100
    print(f'length of array:{n}')
    sum = 0
    ma = 0
    mi = 1000000000000
    for j in range(1):

        A = randList(1300,i*10000)
        st = time.process_time()

        inplaceRadixSort(A , len(A) )

        et = time.process_time()
        res = et - st
        sum+=res
        mi = min(mi,res)
        ma = max(ma, res)
    x.append(n)
    minTime.append(mi)
    maxTime.append(ma)
    average.append(sum/10)
    print('CPU Mean Execution time:', sum/10, 'Max:',ma,' Min:',mi,' seconds')
# Out:
# length of array:100
# CPU Mean Execution time: 0.053125 Max: 0.53125  Min: 0.53125  seconds
# length of array:200
# CPU Mean Execution time: 0.109375 Max: 1.09375  Min: 1.09375  seconds
# length of array:300
# CPU Mean Execution time: 0.175 Max: 1.75  Min: 1.75  seconds
# length of array:400
# CPU Mean Execution time: 0.21875 Max: 2.1875  Min: 2.1875  seconds
# length of array:500
# CPU Mean Execution time: 0.275 Max: 2.75  Min: 2.75  seconds
# length of array:600
# CPU Mean Execution time: 0.325 Max: 3.25  Min: 3.25  seconds
# length of array:700
# CPU Mean Execution time: 0.41875 Max: 4.1875  Min: 4.1875  seconds
# length of array:800
# CPU Mean Execution time: 0.4796875 Max: 4.796875  Min: 4.796875  seconds
# length of array:900
# CPU Mean Execution time: 0.55 Max: 5.5  Min: 5.5  seconds
# length of array:1000
# CPU Mean Execution time: 0.621875 Max: 6.21875  Min: 6.21875  seconds

# %%
plt.plot(x, average, label='Average')
plt.legend()
plt.title('radix sort')
plt.show()

# %%
x = []
average = []
minTime = []
maxTime = []
for i in range(1, 11):
    n = i * 100
    print(f'length of array:{n}')
    sum = 0
    ma = 0
    mi = 1000000000000
    for j in range(1):
        A = randList(1300, i * 1000000)
        st = time.process_time()

        A.sort()

        et = time.process_time()
        res = et - st
        sum += res
        mi = min(mi, res)
        ma = max(ma, res)
    x.append(n)
    minTime.append(mi)
    maxTime.append(ma)
    average.append(sum / 10)
    print('CPU Mean Execution time:', sum / 10, 'Max:', ma, ' Min:', mi, ' seconds')
plt.plot(x, average, label='Average')
plt.legend()
plt.title('python sort')
plt.show()
# Out:
# length of array:100
# CPU Mean Execution time: 0.015625 Max: 0.15625  Min: 0.15625  seconds
# length of array:200
# CPU Mean Execution time: 0.03125 Max: 0.3125  Min: 0.3125  seconds
# length of array:300
# CPU Mean Execution time: 0.059375 Max: 0.59375  Min: 0.59375  seconds
# length of array:400
# CPU Mean Execution time: 0.071875 Max: 0.71875  Min: 0.71875  seconds
# length of array:500
# CPU Mean Execution time: 0.103125 Max: 1.03125  Min: 1.03125  seconds
# length of array:600
# CPU Mean Execution time: 0.096875 Max: 0.96875  Min: 0.96875  seconds
# length of array:700
# CPU Mean Execution time: 0.109375 Max: 1.09375  Min: 1.09375  seconds
# length of array:800
# CPU Mean Execution time: 0.1390625 Max: 1.390625  Min: 1.390625  seconds
# length of array:900
# CPU Mean Execution time: 0.140625 Max: 1.40625  Min: 1.40625  seconds
# length of array:1000
# CPU Mean Execution time: 0.15625 Max: 1.5625  Min: 1.5625  seconds
